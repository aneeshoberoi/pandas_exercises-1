# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep='|')

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.head
# Out:
# <bound method DataFrame.head of      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 10        11   39      F          other    30329
# 11        12   28      F          other    06405
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# ...

# %%
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
newdf=pd.DataFrame(users.groupby('occupation').age.mean())

# %%
newdf
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
genderdf=pd.DataFrame(users.loc[users['gender']=='M'].groupby('occupation').user_id.count())
genderdf.insert(1, 'total_count',users.groupby('occupation').user_id.count(),False)

# %%
genderdf
# Out:
#                user_id  total_count
# occupation
# administrator       43           79
# artist              15           28
# doctor               7            7
# educator            69           95
# engineer            65           67
# entertainment       16           18
# executive           29           32
# healthcare           5           16
# homemaker            1            7
# lawyer              10           12
# librarian           22           51
# marketing           16           26
# none                 5            9
# other               69          105
# programmer          60           66
# retired             13           14
# salesman             9           12
# scientist           28           31
# student            136          196
# technician          26           27
# writer              26           45

# %%
genderdf=genderdf.rename(columns={'user_id':'male_count'})

# %%
genderdf.dtypes
# Out:
# male_count     int64
# total_count    int64
# dtype: object

# %%
genderdf['male_ratio']=genderdf['male_count']/genderdf['total_count']

# %%
genderdf.sort_values('male_ratio',ascending=False)
# Out:
#                male_count  total_count  male_ratio
# occupation
# doctor                  7            7    1.000000
# engineer               65           67    0.970149
# technician             26           27    0.962963
# retired                13           14    0.928571
# programmer             60           66    0.909091
# executive              29           32    0.906250
# scientist              28           31    0.903226
# entertainment          16           18    0.888889
# lawyer                 10           12    0.833333
# salesman                9           12    0.750000
# educator               69           95    0.726316
# student               136          196    0.693878
# other                  69          105    0.657143
# marketing              16           26    0.615385
# writer                 26           45    0.577778
# none                    5            9    0.555556
# administrator          43           79    0.544304
# ...

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').age.agg({'max','min'})
# Out:
#                max  min
# occupation
# administrator   70   21
# artist          48   19
# doctor          64   28
# educator        63   23
# engineer        70   22
# entertainment   50   15
# executive       69   22
# healthcare      62   22
# homemaker       50   20
# lawyer          53   21
# librarian       69   23
# marketing       55   24
# none            55   11
# other           64   13
# programmer      63   20
# retired         73   51
# salesman        66   18
# scientist       55   23
# student         42    7
# technician      55   21
# writer          60   18

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation','gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
genderdf['pct_female']=1-genderdf['male_ratio']
genderdf
# Out:
#                male_count  total_count  male_ratio  pct_female
# occupation
# administrator          43           79    0.544304    0.455696
# artist                 15           28    0.535714    0.464286
# doctor                  7            7    1.000000    0.000000
# educator               69           95    0.726316    0.273684
# engineer               65           67    0.970149    0.029851
# entertainment          16           18    0.888889    0.111111
# executive              29           32    0.906250    0.093750
# healthcare              5           16    0.312500    0.687500
# homemaker               1            7    0.142857    0.857143
# lawyer                 10           12    0.833333    0.166667
# librarian              22           51    0.431373    0.568627
# marketing              16           26    0.615385    0.384615
# none                    5            9    0.555556    0.444444
# other                  69          105    0.657143    0.342857
# ...
